# %%
from matplotlib import pyplot as plt
import numpy as np
import glob
from matplotlib import cm

# %% [markdown]
# ## plot demeter fit result
# Gather up data for chi and R space; plot chi in a loop

# %%
def plot(sample):
    plt.figure()
    plt.subplot(1,2,1)
    filename_chi = glob.glob('/Users/sophia/ownCloud/PhD/Statistic Analysis/demeter/{:s}'.format(sample)+'*.k2')
#     print(filename_chi)
    experiment = np.genfromtxt(filename_chi[0])
    experiment = experiment[:,(0,1)]
    cmap = cm.get_cmap('winter')
    for file in filename_chi:
        data = np.genfromtxt(file)[:,2]
        if 'OSCdCd' in file[-12:-3]:
            label = 'O S Cd Cd'
            i = 4
        elif 'OSCd' in file[-12:-3]:
            label = 'O S Cd'
            i = 3
        elif 'CdCd' in file[-12:-3]:
            label = 'S Cd'
            i = 2
        elif 'CdS' in file[-12:-3]:
            label = 'S'
            i = 1
        elif 'CdOS' in file[-12:-3]:
            label = 'O S'
            i = 0
        plt.plot(experiment[:,0],experiment[:,1] - 1.5*i,'ko', markersize = 0.5)
        plt.plot(experiment[:,0],data -1.5*i,label=label,color = cmap((float(i)*2+2)/10),linewidth=0.5)
        plt.plot(experiment[:,0],data-experiment[:,1] -6,label=label,color = cmap((float(i)*2+2)/10),linewidth=0.5)
        
    plt.xlim([2,18])
    if sample == 'M322':
        plt.ylim([-7,1])
    else:
        plt.ylim([-7,1])   
    plt.xlabel('k ($\AA$)')
    plt.ylabel('$k^2\chi(k)$')
    plt.legend(loc='upper right')
    
    plt.subplot(1,2,2)
    filename_r = glob.glob('/Users/sophia/ownCloud/PhD/Statistic Analysis/demeter/{:s}'.format(sample)+'*.rmag')
    experiment = np.genfromtxt(filename_r[0])
    experiment = experiment[:,(0,1)]
    cmap = cm.get_cmap('winter')
    for file in filename_r:
        print(file[-12:-3])
        data = np.genfromtxt(file)[:,2]
        if 'OSCdCd' in file[-12:-3]:
            label = 'O S Cd Cd'
            i = 4
        elif 'OSCd' in file[-12:-3]:
            label = 'O S Cd'
            i = 3
        elif 'CdCd' in file[-12:-3]:
            label = 'S Cd'
            i = 2
        elif 'CdS' in file[-12:-3]:
            label = 'S'
            i = 1
        elif 'CdOS' in file[-12:-3]:
            label = 'O S'
            i = 0
        
        plt.plot(experiment[:,0],experiment[:,1] - 1.5*i,'ko', markersize = 0.5)
        plt.plot(experiment[:,0],data -1.5*i,label=label,color = cmap((float(i)*2+2)/10),linewidth=0.5)
       
    plt.xlim([0,5])
    plt.xlabel('Radial distance ($\AA$)')
    plt.yticks([])
    plt.legend(loc='upper right')
    plt.title(' Artemis fitting result in k space and its Fourier Transform with each shell for sample'+sample)
    plt.tight_layout()
    plt.savefig('/Users/sophia/ownCloud/PhD/Statistic Analysis/figure/artemis_fit_{:s}.pdf'.format(sample),format='pdf')
    
plot('M311')
plot('M322')
# Out:
# 11_CdOS.r
# 11_CdCd.r
# _CdOSCd.r
# 311_CdS.r
# 22_CdCd.r
# dOSCdCd.r
# 22_CdOS.r
# _CdOSCd.r
# 322_CdS.r

# %% [markdown]
# Plot kq

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-14-9ff8b63dabb3> in <module>
# ----> 1 from xafs import *
#
# ~/ownCloud/PhD/Statistic Analysis/EXAFS_analysis/xafs/__init__.py in <module>
#       2
#       3 import numpy as np
# ----> 4 import pandas as pd
#       5 import matplotlib.pyplot as plt
#       6 from scipy.interpolate import interp1d,UnivariateSpline,LSQUnivariateSpline
#
# ModuleNotFoundError: No module named 'pandas'
