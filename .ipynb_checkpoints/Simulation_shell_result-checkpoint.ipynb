# %% [markdown]
# Plot FEFF calucation shell by shell

# %%
from matplotlib import pyplot as plt
import numpy as np
import glob

# %% [markdown]
# Add colour map to show the shell change

# %%
from matplotlib import cm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-42-f93f6d80af4d> in <module>
#       1 from matplotlib import cm
# ----> 2 from colorspacious import cspace_converter
#       3 from collections import OrderedDict
#
# ModuleNotFoundError: No module named 'colorspacious'

# %%
filename = glob.glob('/Users/Sophia/ownCloud/PhD/Simulation/CdS/FEFF/feff_shell/*')
feff_data={}
plt.figure()
for i,file in enumerate(filename):
    label = file[-11:-4]
    feff_data[label] = np.genfromtxt(file)[:,(0,3)]
    plt.plot(feff_data[label][:,0],feff_data[label][:,1]-0.2*(int(label[-1])-1),label=label)
bulk = np.genfromtxt('/Users/Sophia/ownCloud/PhD/Experiment_Analysis/CdS/CdS_XAFS_CdK_mu_2018.xmu')[:,(0,2)]
for i in range(4):
    plt.plot(bulk[:,0]+49,bulk[:,1]-0.2*i,'k.',markersize=0.5,label='Zinc Blend')
plt.legend()
plt.ylim([0.2,1.1])
plt.xlim([26730,27100])
plt.xlabel('energy')
plt.ylabel('mu')
# Out:
# Text(0, 0.5, 'mu')
